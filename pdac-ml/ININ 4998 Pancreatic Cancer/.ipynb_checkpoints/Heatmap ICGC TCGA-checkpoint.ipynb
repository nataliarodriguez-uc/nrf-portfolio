# %%
import pandas as pd

TCGAred = pd.read_csv("TCGA_271_complete.csv")
TCGAred.loc[TCGAred['OS'] == "DECEASED", 'OS'] = '1'
TCGAred.loc[TCGAred['OS'] == "LIVING", 'OS'] = '0'
TCGAred

ICGCred = pd.read_csv("ICGC_216_complete.csv")
display(TCGAred,ICGCred)
# Out:
#       ACAP3  ADSSL1    ALG9  ALKBH5  ANAPC2  ANKIB1   AP2A2     AQR  ARHGAP32  \
# 0   -0.5177 -0.3113 -0.0048  0.1456 -0.3448 -0.8028  0.9185  0.1447    0.2914
# 1    0.1502 -0.0645  1.5986 -0.2518 -0.5336 -0.8363  0.2491 -0.1762    1.0107
# 2    2.3888  1.0962  0.9665  0.3432 -0.5442  0.0673 -0.7583 -0.5851    0.7091
# 3   -0.4301 -0.4296 -0.8378 -0.0840 -0.3201 -0.2570 -1.0043  0.8140    0.1189
# 4   -0.2311 -0.2609  0.4083 -0.0687 -0.2338 -0.0607  0.2441 -0.3606    0.2802
# ..      ...     ...     ...     ...     ...     ...     ...     ...       ...
# 172  0.0234 -0.2887 -0.5726  0.0376  0.8748 -0.3141 -0.4071 -0.3485   -1.1484
# 173  0.2151 -0.2734 -1.1478 -0.0199 -0.3667 -0.1877 -0.1078 -0.5288   -0.4848
# 174  0.8742 -0.1243 -0.3882 -0.2429 -0.5576 -0.1913 -0.8302 -0.5368    0.4983
# 175 -0.4936 -0.4647 -0.6145 -0.8443 -0.1490 -0.8357  0.1059  0.1286    0.0753
# 176 -0.4999 -0.5374 -0.7660  0.0696  0.7437 -0.3946 -0.8870  1.1356   -1.3983
#
# ...

# %%
import numpy as np
import seaborn as sns

sns.heatmap(ICGCred)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(TCGAred)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-cf391afa6fb6> in <module>
# ----> 1 sns.heatmap(TCGAred)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     556     if square:
#     557         ax.set_aspect("equal")
# --> 558     plotter.plot(ax, cbar_ax, kwargs)
#     559     return ax
#     560
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/matrix.py in plot(self, ax, cax, kws)
# ...
